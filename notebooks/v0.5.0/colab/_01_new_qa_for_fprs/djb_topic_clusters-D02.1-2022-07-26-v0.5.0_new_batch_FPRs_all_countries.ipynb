# %% [markdown]
# # Purpose
#
# ### 2022-07-18
# In this notebook we'll run a batch of countries through a new FPR output process.
# Instead of saving data to google sheets, we'll save:
# - FPR outputs to a GCS bucket (JSON)
# - FPR summary to BigQuery
# - FPR details to BigQuery
#
# We can then use the summary & details in a Mode dashboard for inspection (if needed).
#
# See this dashboard for more information about the model coverage & filters.
# https://app.mode.com/reddit/reports/b99c94984018

# %% [markdown]
# # Imports & notebook setup

# %%
# %load_ext autoreload
# %autoreload 2

# Register bigquery magic (only needed for laptop/local, not colab)
# %load_ext google.cloud.bigquery

# %%
# colab auth for BigQuery, google drive, & google sheets (gspread)
from google.colab import auth, files, drive
from google.auth import default
import sys  # need sys for mounting gdrive path

auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# ## Install custom library

# %% [markdown]
# ### Append google drive path so we can install library from there

# %%
# Attach google drive & import my python utility functions
# if drive.mount() fails, you can also:
#   MANUALLY CLICK ON "Mount Drive"
import sys


g_drive_root = '/content/drive'

try:
    drive.mount(g_drive_root, force_remount=True)
    print('   Authenticated & mounted Google Drive')
    
except Exception as e:
    try:
        drive._mount(g_drive_root, force_remount=True)
        print('   Authenticated & mounted Google Drive')
    except Exception as e:
        print(e)
        raise Exception('You might need to manually mount google drive to colab')

l_paths_to_append = [
    f'{g_drive_root}/MyDrive/Colab Notebooks',

    # need to append the path to subclu so that colab can import things properly
    f'{g_drive_root}/MyDrive/Colab Notebooks/subreddit_clustering_i18n'
]
for path_ in l_paths_to_append:
    if path_ in sys.path:
        sys.path.remove(path_)
    print(f" Appending path: {path_}")
    sys.path.append(path_)
# Out:
# Mounted at /content/drive
#    Authenticated & mounted Google Drive
#  Appending path: /content/drive/MyDrive/Colab Notebooks
#  Appending path: /content/drive/MyDrive/Colab Notebooks/subreddit_clustering_i18n

# %% [markdown]
# ### Install library

# %%
# install subclu & libraries needed to read parquet files from GCS & spreadsheets
#  make sure to use the [colab] `extra` because it includes colab-specific libraries
module_path = f"{g_drive_root}/MyDrive/Colab Notebooks/subreddit_clustering_i18n/[colab]"

# !pip install -e $"$module_path" --quiet
# Out:
#      |████████████████████████████████| 10.1 MB 5.2 MB/s
#      |████████████████████████████████| 14.2 MB 12.6 MB/s
#      |████████████████████████████████| 965 kB 46.3 MB/s
#      |████████████████████████████████| 144 kB 55.6 MB/s
#      |████████████████████████████████| 76 kB 4.2 MB/s
#      |████████████████████████████████| 285 kB 49.1 MB/s
#      |████████████████████████████████| 13.2 MB 18.4 MB/s
#      |████████████████████████████████| 79.9 MB 98 kB/s
#      |████████████████████████████████| 140 kB 46.0 MB/s
#      |████████████████████████████████| 715 kB 48.8 MB/s
#      |████████████████████████████████| 74 kB 3.1 MB/s
#      |████████████████████████████████| 112 kB 47.9 MB/s
#      |████████████████████████████████| 181 kB 68.4 MB/s
#      |████████████████████████████████| 79 kB 7.7 MB/s
#      |████████████████████████████████| 1.1 MB 49.3 MB/s
#      |████████████████████████████████| 81 kB 1.2 MB/s
#      |████████████████████████████████| 146 kB 67.2 MB/s
#      |████████████████████████████████| 596 kB 55.0 MB/s
#      |████████████████████████████████| 78 kB 7.0 MB/s
#      |████████████████████████████████| 54 kB 2.7 MB/s
#      |████████████████████████████████| 1.1 MB 44.2 MB/s
#      |████████████████████████████████| 271 kB 62.1 MB/s
#      |████████████████████████████████| 144 kB 44.6 MB/s
#      |████████████████████████████████| 94 kB 2.3 MB/s
#      |████████████████████████████████| 63 kB 1.5 MB/s
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for alembic (setup.py) ... done
#   Building wheel for databricks-cli (setup.py) ... done
#   Building wheel for retrying (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.1.0 which is incompatible.

# %% [markdown]
# ## Regular Imports

# %%
import os
from datetime import datetime

from google.cloud import bigquery

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib_venn import venn2_unweighted, venn3_unweighted
from tqdm import tqdm


# os.environ['GOOGLE_CLOUD_PROJECT'] = 'data-science-prod-218515'
os.environ['GOOGLE_CLOUD_PROJECT'] = 'data-prod-165221'

# %% [markdown]
# ## Custom imports

# %%
# subclu imports
import subclu
from subclu.utils.eda import (
    setup_logging, counts_describe, value_counts_and_pcts,
    notebook_display_config, print_lib_versions,
    style_df_numeric, reorder_array,
)
from subclu.models.clustering_utils import (
    create_dynamic_clusters,
    convert_distance_or_ab_to_list_for_fpr,
    get_primary_topic_mix_cols,
)
from subclu.utils.hydra_config_loader import LoadHydraConfig
from subclu.models.reshape_clusters_v050 import (
    get_table_for_optimal_dynamic_cluster_params,
    CreateFPRs,
    get_dynamic_cluster_summary,
    get_geo_relevant_subreddits_and_cluster_labels,
    get_fpr_cluster_per_row_summary,
    reshape_df_1_cluster_per_row,
)

setup_logging()
notebook_display_config()
print_lib_versions([pd, np])
# Out:
# python		v 3.7.13
# ===
# pandas		v: 1.3.5
# numpy		v: 1.21.6

# %% [markdown]
# # Checklist to re-run FPRs
#
# - Update list of countries to run
# - Update path to save outputs (in GCS)
#
#
# With this new process we should only need a list of country names to get an FPR output. Everything else should be automated as long as we load from the default config.

# %% [markdown]
# ## Load English-countries configuration

# %%
cfg_fpr_not_en = LoadHydraConfig(
    config_name='fpr_v050-2022-07-26-non_english.yaml',
    config_path="../config",
    # overrides=[
    #     f"partition_dt=2022-07-24",
    # ],
)

print([k for k in cfg_fpr_not_en.config_dict.keys()])
cfg_fpr_not_en.config_dict
# Out:
# ['description', 'output_bucket', 'gcs_output_path', 'cluster_labels_table', 'partition_dt', 'geo_relevance_table', 'geo_min_users_percent_by_subreddit_l28', 'geo_min_country_standardized_relevance', 'qa_table', 'qa_pt', 'target_countries']
# {'cluster_labels_table': 'reddit-employee-datasets.david_bermejo.subclu_v0050_subreddit_clusters_c_full',
#  'description': "Base config to test FPR creation. IE (Ireland) is here because it's a small country",
#  'gcs_output_path': 'i18n_topic_model_batch/fpr/runs',
#  'geo_min_country_standardized_relevance': 2.4,
#  'geo_min_users_percent_by_subreddit_l28': 0.14,
#  'geo_relevance_table': 'reddit-employee-datasets.david_bermejo.subclu_subreddit_relevance_beta_20220725',
#  'output_bucket': 'i18n-subreddit-clustering',
#  'partition_dt': '2022-07-25',
#  'qa_pt': '2022-07-25',
#  'qa_table': 'reddit-employee-datasets.david_bermejo.subclu_v0050_subreddit_clusters_c_qa_flags',
#  'target_countries': ['IN',
#   'IE',
#   'DE',
#   'AT',
#   'CH',
#   'PT',
#   'BR',
#   'FR',
#   'IT',
#   'MX',
#   'ES',
#   'AR',
#   'CO',
#   'CR',
#   'PA',
#   'SE',
#   'RO',
#   'NL',
#   'GR',
#   'BE',
#   'PL',
#   'TR',
#   'SA',
#   'PH',
#   'GT',
#   'CL',
#   'FI']}

# %%
cfg_fpr_en = LoadHydraConfig(
    config_name='fpr_v050-2022-07-26-english_countries.yaml',
    config_path="../config",
    # overrides=[
    #     f"target_countries={l_target_countries}",
    #     f"partition_dt=2022-07-24",
    # ],
)

print([k for k in cfg_fpr_en.config_dict.keys()])
cfg_fpr_en.config_dict
# Out:
# ['description', 'target_countries', 'output_bucket', 'gcs_output_path', 'cluster_labels_table', 'partition_dt', 'geo_relevance_table', 'geo_min_users_percent_by_subreddit_l28', 'geo_min_country_standardized_relevance', 'qa_table', 'qa_pt']
# {'cluster_labels_table': 'reddit-employee-datasets.david_bermejo.subclu_v0050_subreddit_clusters_c_full',
#  'description': 'Base config to test FPR creation',
#  'gcs_output_path': 'i18n_topic_model_batch/fpr/runs',
#  'geo_min_country_standardized_relevance': 3.0,
#  'geo_min_users_percent_by_subreddit_l28': 0.15,
#  'geo_relevance_table': 'reddit-employee-datasets.david_bermejo.subclu_subreddit_relevance_beta_20220725',
#  'output_bucket': 'i18n-subreddit-clustering',
#  'partition_dt': '2022-07-25',
#  'qa_pt': '2022-07-25',
#  'qa_table': 'reddit-employee-datasets.david_bermejo.subclu_v0050_subreddit_clusters_c_qa_flags',
#  'target_countries': ['AU', 'GB', 'CA']}

# %% [markdown]
# # Run `create_fprs()` method
#
# This method should do everything needed to create FPRs.

# %% [markdown]
# ### Mainly English-speaking countries

# %%
# %%time
fprs_en = CreateFPRs(
    **cfg_fpr_en.config_dict
)

# run all countries
fprs_en.create_fprs()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]17:30:22 | INFO | "== Country: AU =="
# 17:30:22 | INFO | "Getting geo-relevant subreddits in model for AU..."
# 17:30:31 | INFO | " (607, 160)  <- df_shape"
# 17:30:31 | INFO | " (606, 161) <- Shape AFTER dropping subreddits with covid in title"
# 17:30:31 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:03<00:14,  3.61s/it]
#  40%|████      | 2/5 [00:07<00:10,  3.65s/it]
#  60%|██████    | 3/5 [00:10<00:07,  3.66s/it]
#  80%|████████  | 4/5 [00:14<00:03,  3.67s/it]
# 100%|██████████| 5/5 [00:18<00:00,  3.69s/it]
# 17:30:50 | INFO | "  6 <-- Optimal N"
# 17:30:50 | INFO | "Assigning clusters based on optimal N..."
# 17:30:54 | INFO | "Getting QA and summary at cluster_level..."
# 17:30:54 | INFO | "(83, 23)  <- df.shape full summary"
# 17:30:54 | INFO | "Adding metadata to df_top_level_summary..."
# 17:30:54 | INFO | "Creating FPR output..."
# 17:30:54 | INFO | "  (559, 15) <- df_fpr.shape"
# 17:30:54 | INFO | "** Checking FPR output with expected QA output... **"
# 17:30:54 | INFO | "  559 SEED subreddits in output"
# 17:30:54 | INFO | "  559 SEED subreddits expected"
# 17:30:54 | INFO | "SEED subreddit IDS match expected output"
# 17:30:54 | INFO | "  362 RECOMMEND subreddits in output"
# 17:30:54 | INFO | "  362 RECOMMEND subreddits expected"
# 17:30:54 | INFO | "RECOMMEND subreddit IDS match expected output"
# 17:30:55 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/fpr_json/AU_2022-07-26_173022.json"
# 17:30:55 | INFO | "Upload complete!"
# 17:30:55 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/df_fpr"
# 17:30:56 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/df_fpr_qa_summary"
# 17:30:56 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/df_fpr_cluster_summary"
# 17:30:57 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/df_dynamic_clusters"
#  33%|███▎      | 1/3 [00:35<01:11, 35.51s/it]17:30:57 | INFO | "== Country: GB =="
# 17:30:57 | INFO | "Getting geo-relevant subreddits in model for GB..."
# 17:31:13 | INFO | " (2999, 160)  <- df_shape"
# 17:31:13 | INFO | " (2998, 161) <- Shape AFTER dropping subreddits with covid in title"
# 17:31:13 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:12<00:50, 12.63s/it]
#  40%|████      | 2/5 [00:25<00:37, 12.61s/it]
#  60%|██████    | 3/5 [00:39<00:26, 13.29s/it]
#  80%|████████  | 4/5 [00:52<00:13, 13.16s/it]
# 100%|██████████| 5/5 [01:05<00:00, 13.10s/it]
# 17:32:19 | INFO | "  6 <-- Optimal N"
# 17:32:19 | INFO | "Assigning clusters based on optimal N..."
# 17:32:32 | INFO | "Getting QA and summary at cluster_level..."
# 17:32:32 | INFO | "(354, 23)  <- df.shape full summary"
# 17:32:32 | INFO | "Adding metadata to df_top_level_summary..."
# 17:32:32 | INFO | "Creating FPR output..."
# 17:32:33 | INFO | "  (2894, 15) <- df_fpr.shape"
# 17:32:33 | INFO | "** Checking FPR output with expected QA output... **"
# 17:32:33 | INFO | "2,894 SEED subreddits in output"
# 17:32:33 | INFO | "2,894 SEED subreddits expected"
# 17:32:33 | INFO | "SEED subreddit IDS match expected output"
# 17:32:33 | INFO | "1,762 RECOMMEND subreddits in output"
# 17:32:33 | INFO | "1,762 RECOMMEND subreddits expected"
# 17:32:33 | INFO | "RECOMMEND subreddit IDS match expected output"
# 17:32:33 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/fpr_json/GB_2022-07-26_173022.json"
# 17:32:34 | INFO | "Upload complete!"
# 17:32:34 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/df_fpr"
# 17:32:34 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/df_fpr_qa_summary"
# 17:32:35 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/df_fpr_cluster_summary"
# 17:32:35 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/df_dynamic_clusters"
#  67%|██████▋   | 2/3 [02:14<01:12, 72.86s/it]17:32:36 | INFO | "== Country: CA =="
# 17:32:36 | INFO | "Getting geo-relevant subreddits in model for CA..."
# 17:32:51 | INFO | " (2373, 160)  <- df_shape"
# 17:32:51 | INFO | " (2373, 161) <- Shape AFTER dropping subreddits with covid in title"
# 17:32:51 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:10<00:41, 10.40s/it]
#  40%|████      | 2/5 [00:20<00:31, 10.50s/it]
#  60%|██████    | 3/5 [00:31<00:21, 10.51s/it]
#  80%|████████  | 4/5 [00:41<00:10, 10.49s/it]
# 100%|██████████| 5/5 [00:52<00:00, 10.54s/it]
# 17:33:44 | INFO | "  8 <-- Optimal N"
# 17:33:44 | INFO | "Assigning clusters based on optimal N..."
# 17:33:55 | INFO | "Getting QA and summary at cluster_level..."
# 17:33:55 | INFO | "(222, 23)  <- df.shape full summary"
# 17:33:55 | INFO | "Adding metadata to df_top_level_summary..."
# 17:33:55 | INFO | "Creating FPR output..."
# 17:33:55 | INFO | "  (2334, 15) <- df_fpr.shape"
# 17:33:55 | INFO | "** Checking FPR output with expected QA output... **"
# 17:33:55 | INFO | "2,334 SEED subreddits in output"
# 17:33:55 | INFO | "2,334 SEED subreddits expected"
# 17:33:55 | INFO | "SEED subreddit IDS match expected output"
# 17:33:55 | INFO | "1,419 RECOMMEND subreddits in output"
# 17:33:55 | INFO | "1,419 RECOMMEND subreddits expected"
# 17:33:55 | INFO | "RECOMMEND subreddit IDS match expected output"
# 17:33:56 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/fpr_json/CA_2022-07-26_173022.json"
# 17:33:56 | INFO | "Upload complete!"
# 17:33:56 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/df_fpr"
# 17:33:57 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/df_fpr_qa_summary"
# 17:33:57 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/df_fpr_cluster_summary"
# 17:33:58 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_173022/df_dynamic_clusters"
# 100%|██████████| 3/3 [03:36<00:00, 72.27s/it]
# CPU times: user 2min 50s, sys: 2.37 s, total: 2min 53s
# Wall time: 3min 36s

# %% [markdown]
# ### Mainly non-English speaking countries

# %%
# %%time
fprs_non_en = CreateFPRs(
    **cfg_fpr_not_en.config_dict
)

# run all countries
fprs_non_en.create_fprs()
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]23:34:58 | INFO | "== Country: IN =="
# 23:34:58 | INFO | "Getting geo-relevant subreddits in model for IN..."
# 23:35:02 | INFO | " (798, 160)  <- df_shape"
# 23:35:02 | INFO | " (798, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:35:02 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:04<00:18,  4.60s/it]
#  40%|████      | 2/5 [00:09<00:14,  4.99s/it]
#  60%|██████    | 3/5 [00:15<00:10,  5.31s/it]
#  80%|████████  | 4/5 [00:20<00:05,  5.23s/it]
# 100%|██████████| 5/5 [00:25<00:00,  5.16s/it]
# 23:35:28 | INFO | "  6 <-- Optimal N"
# 23:35:28 | INFO | "Assigning clusters based on optimal N..."
# 23:35:34 | INFO | "Getting QA and summary at cluster_level..."
# 23:35:34 | INFO | "(108, 23)  <- df.shape full summary"
# 23:35:34 | INFO | "Adding metadata to df_top_level_summary..."
# 23:35:34 | INFO | "Creating FPR output..."
# 23:35:34 | INFO | "  (690, 15) <- df_fpr.shape"
# 23:35:34 | INFO | "** Checking FPR output with expected QA output... **"
# 23:35:34 | INFO | "  690 SEED subreddits in output"
# 23:35:34 | INFO | "  690 SEED subreddits expected"
# 23:35:34 | INFO | "SEED subreddit IDS match expected output"
# 23:35:34 | INFO | "  344 RECOMMEND subreddits in output"
# 23:35:34 | INFO | "  344 RECOMMEND subreddits expected"
# 23:35:34 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:35:34 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/IN_2022-07-26_233458.json"
# 23:35:35 | INFO | "Upload complete!"
# 23:35:35 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:35:35 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:35:36 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:35:36 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#   4%|▎         | 1/27 [00:37<16:22, 37.78s/it]23:35:36 | INFO | "== Country: IE =="
# 23:35:36 | INFO | "Getting geo-relevant subreddits in model for IE..."
# 23:35:39 | INFO | " (383, 160)  <- df_shape"
# 23:35:39 | INFO | " (383, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:35:39 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:11,  2.91s/it]
#  40%|████      | 2/5 [00:05<00:08,  2.94s/it]
#  60%|██████    | 3/5 [00:08<00:05,  2.96s/it]
#  80%|████████  | 4/5 [00:11<00:03,  3.00s/it]
# 100%|██████████| 5/5 [00:14<00:00,  2.99s/it]
# 23:35:54 | INFO | "  6 <-- Optimal N"
# 23:35:54 | INFO | "Assigning clusters based on optimal N..."
# 23:35:57 | INFO | "Getting QA and summary at cluster_level..."
# 23:35:58 | INFO | "(63, 23)  <- df.shape full summary"
# 23:35:58 | INFO | "Adding metadata to df_top_level_summary..."
# 23:35:58 | INFO | "Creating FPR output..."
# 23:35:58 | INFO | "  (362, 15) <- df_fpr.shape"
# 23:35:58 | INFO | "** Checking FPR output with expected QA output... **"
# 23:35:58 | INFO | "  362 SEED subreddits in output"
# 23:35:58 | INFO | "  362 SEED subreddits expected"
# 23:35:58 | INFO | "SEED subreddit IDS match expected output"
# 23:35:58 | INFO | "  255 RECOMMEND subreddits in output"
# 23:35:58 | INFO | "  255 RECOMMEND subreddits expected"
# 23:35:58 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:35:58 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/IE_2022-07-26_233458.json"
# 23:35:58 | INFO | "Upload complete!"
# 23:35:58 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:35:58 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:35:59 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:35:59 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#   7%|▋         | 2/27 [01:00<12:05, 29.03s/it]23:35:59 | INFO | "== Country: DE =="
# 23:35:59 | INFO | "Getting geo-relevant subreddits in model for DE..."
# 23:36:03 | INFO | " (764, 160)  <- df_shape"
# 23:36:03 | INFO | " (764, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:36:03 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:04<00:16,  4.24s/it]
#  40%|████      | 2/5 [00:08<00:13,  4.48s/it]
#  60%|██████    | 3/5 [00:13<00:08,  4.42s/it]
#  80%|████████  | 4/5 [00:17<00:04,  4.44s/it]
# 100%|██████████| 5/5 [00:22<00:00,  4.44s/it]
# 23:36:25 | INFO | "  9 <-- Optimal N"
# 23:36:25 | INFO | "Assigning clusters based on optimal N..."
# 23:36:30 | INFO | "Getting QA and summary at cluster_level..."
# 23:36:30 | INFO | "(75, 23)  <- df.shape full summary"
# 23:36:30 | INFO | "Adding metadata to df_top_level_summary..."
# 23:36:30 | INFO | "Creating FPR output..."
# 23:36:30 | INFO | "  (689, 15) <- df_fpr.shape"
# 23:36:30 | INFO | "** Checking FPR output with expected QA output... **"
# 23:36:30 | INFO | "  689 SEED subreddits in output"
# 23:36:30 | INFO | "  689 SEED subreddits expected"
# 23:36:30 | INFO | "SEED subreddit IDS match expected output"
# 23:36:30 | INFO | "  352 RECOMMEND subreddits in output"
# 23:36:30 | INFO | "  352 RECOMMEND subreddits expected"
# 23:36:30 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:36:30 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/DE_2022-07-26_233458.json"
# 23:36:30 | INFO | "Upload complete!"
# 23:36:30 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:36:31 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:36:31 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:36:31 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  11%|█         | 3/27 [01:32<12:11, 30.48s/it]23:36:31 | INFO | "== Country: AT =="
# 23:36:31 | INFO | "Getting geo-relevant subreddits in model for AT..."
# 23:36:39 | INFO | " (188, 160)  <- df_shape"
# 23:36:39 | INFO | " (188, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:36:39 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:10,  2.52s/it]
#  40%|████      | 2/5 [00:05<00:07,  2.54s/it]
#  60%|██████    | 3/5 [00:07<00:05,  2.52s/it]
#  80%|████████  | 4/5 [00:10<00:02,  2.56s/it]
# 100%|██████████| 5/5 [00:13<00:00,  2.76s/it]
# 23:36:53 | INFO | "  5 <-- Optimal N"
# 23:36:53 | INFO | "Assigning clusters based on optimal N..."
# 23:36:56 | INFO | "Getting QA and summary at cluster_level..."
# 23:36:56 | INFO | "(43, 23)  <- df.shape full summary"
# 23:36:56 | INFO | "Adding metadata to df_top_level_summary..."
# 23:36:56 | INFO | "Creating FPR output..."
# 23:36:56 | INFO | "  (160, 15) <- df_fpr.shape"
# 23:36:56 | INFO | "** Checking FPR output with expected QA output... **"
# 23:36:56 | INFO | "  160 SEED subreddits in output"
# 23:36:56 | INFO | "  160 SEED subreddits expected"
# 23:36:56 | INFO | "SEED subreddit IDS match expected output"
# 23:36:56 | INFO | "   81 RECOMMEND subreddits in output"
# 23:36:56 | INFO | "   81 RECOMMEND subreddits expected"
# 23:36:56 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:36:56 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/AT_2022-07-26_233458.json"
# 23:36:57 | INFO | "Upload complete!"
# 23:36:57 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:36:57 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:36:57 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:36:57 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  15%|█▍        | 4/27 [01:59<11:03, 28.84s/it]23:36:58 | INFO | "== Country: CH =="
# 23:36:58 | INFO | "Getting geo-relevant subreddits in model for CH..."
# 23:37:00 | INFO | " (116, 160)  <- df_shape"
# 23:37:00 | INFO | " (116, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:37:00 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:09,  2.30s/it]
#  40%|████      | 2/5 [00:04<00:06,  2.28s/it]
#  60%|██████    | 3/5 [00:06<00:04,  2.28s/it]
#  80%|████████  | 4/5 [00:09<00:02,  2.26s/it]
# 100%|██████████| 5/5 [00:11<00:00,  2.27s/it]
# 23:37:11 | INFO | "  5 <-- Optimal N"
# 23:37:11 | INFO | "Assigning clusters based on optimal N..."
# 23:37:14 | INFO | "Getting QA and summary at cluster_level..."
# 23:37:14 | INFO | "(28, 23)  <- df.shape full summary"
# 23:37:14 | INFO | "Adding metadata to df_top_level_summary..."
# 23:37:14 | INFO | "Creating FPR output..."
# 23:37:14 | INFO | "  (96, 15) <- df_fpr.shape"
# 23:37:14 | INFO | "** Checking FPR output with expected QA output... **"
# 23:37:14 | INFO | "   96 SEED subreddits in output"
# 23:37:14 | INFO | "   96 SEED subreddits expected"
# 23:37:14 | INFO | "SEED subreddit IDS match expected output"
# 23:37:14 | INFO | "   73 RECOMMEND subreddits in output"
# 23:37:14 | INFO | "   73 RECOMMEND subreddits expected"
# 23:37:14 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:37:14 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/CH_2022-07-26_233458.json"
# 23:37:14 | INFO | "Upload complete!"
# 23:37:14 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:37:15 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:37:15 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:37:15 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  19%|█▊        | 5/27 [02:17<09:07, 24.89s/it]23:37:15 | INFO | "== Country: PT =="
# 23:37:15 | INFO | "Getting geo-relevant subreddits in model for PT..."
# 23:37:24 | INFO | " (158, 160)  <- df_shape"
# 23:37:24 | INFO | " (158, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:37:24 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:09,  2.33s/it]
#  40%|████      | 2/5 [00:04<00:07,  2.36s/it]
#  60%|██████    | 3/5 [00:07<00:04,  2.38s/it]
#  80%|████████  | 4/5 [00:09<00:02,  2.37s/it]
# 100%|██████████| 5/5 [00:11<00:00,  2.38s/it]
# 23:37:36 | INFO | "  7 <-- Optimal N"
# 23:37:36 | INFO | "Assigning clusters based on optimal N..."
# 23:37:38 | INFO | "Getting QA and summary at cluster_level..."
# 23:37:38 | INFO | "(34, 23)  <- df.shape full summary"
# 23:37:38 | INFO | "Adding metadata to df_top_level_summary..."
# 23:37:38 | INFO | "Creating FPR output..."
# 23:37:38 | INFO | "  (141, 15) <- df_fpr.shape"
# 23:37:38 | INFO | "** Checking FPR output with expected QA output... **"
# 23:37:38 | INFO | "  141 SEED subreddits in output"
# 23:37:38 | INFO | "  141 SEED subreddits expected"
# 23:37:38 | INFO | "SEED subreddit IDS match expected output"
# 23:37:38 | INFO | "   85 RECOMMEND subreddits in output"
# 23:37:38 | INFO | "   85 RECOMMEND subreddits expected"
# 23:37:38 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:37:39 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/PT_2022-07-26_233458.json"
# 23:37:39 | INFO | "Upload complete!"
# 23:37:39 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:37:39 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:37:39 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:37:40 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  22%|██▏       | 6/27 [02:41<08:39, 24.74s/it]23:37:40 | INFO | "== Country: BR =="
# 23:37:40 | INFO | "Getting geo-relevant subreddits in model for BR..."
# 23:37:43 | INFO | " (252, 160)  <- df_shape"
# 23:37:43 | INFO | " (252, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:37:43 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:10,  2.64s/it]
#  40%|████      | 2/5 [00:05<00:08,  2.71s/it]
#  60%|██████    | 3/5 [00:08<00:05,  2.69s/it]
#  80%|████████  | 4/5 [00:10<00:02,  2.69s/it]
# 100%|██████████| 5/5 [00:13<00:00,  2.68s/it]
# 23:37:56 | INFO | "  6 <-- Optimal N"
# 23:37:56 | INFO | "Assigning clusters based on optimal N..."
# 23:37:59 | INFO | "Getting QA and summary at cluster_level..."
# 23:37:59 | INFO | "(45, 23)  <- df.shape full summary"
# 23:37:59 | INFO | "Adding metadata to df_top_level_summary..."
# 23:37:59 | INFO | "Creating FPR output..."
# 23:37:59 | INFO | "  (196, 15) <- df_fpr.shape"
# 23:37:59 | INFO | "** Checking FPR output with expected QA output... **"
# 23:37:59 | INFO | "  196 SEED subreddits in output"
# 23:37:59 | INFO | "  196 SEED subreddits expected"
# 23:37:59 | INFO | "SEED subreddit IDS match expected output"
# 23:37:59 | INFO | "   95 RECOMMEND subreddits in output"
# 23:37:59 | INFO | "   95 RECOMMEND subreddits expected"
# 23:37:59 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:37:59 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/BR_2022-07-26_233458.json"
# 23:37:59 | INFO | "Upload complete!"
# 23:37:59 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:38:00 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:38:00 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:38:00 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  26%|██▌       | 7/27 [03:02<07:47, 23.37s/it]23:38:00 | INFO | "== Country: FR =="
# 23:38:00 | INFO | "Getting geo-relevant subreddits in model for FR..."
# 23:38:03 | INFO | " (282, 160)  <- df_shape"
# 23:38:03 | INFO | " (282, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:38:03 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:11,  2.76s/it]
#  40%|████      | 2/5 [00:05<00:08,  2.72s/it]
#  60%|██████    | 3/5 [00:08<00:05,  2.80s/it]
#  80%|████████  | 4/5 [00:11<00:02,  2.93s/it]
# 100%|██████████| 5/5 [00:15<00:00,  3.09s/it]
# 23:38:19 | INFO | "  6 <-- Optimal N"
# 23:38:19 | INFO | "Assigning clusters based on optimal N..."
# 23:38:22 | INFO | "Getting QA and summary at cluster_level..."
# 23:38:22 | INFO | "(48, 23)  <- df.shape full summary"
# 23:38:22 | INFO | "Adding metadata to df_top_level_summary..."
# 23:38:22 | INFO | "Creating FPR output..."
# 23:38:22 | INFO | "  (254, 15) <- df_fpr.shape"
# 23:38:22 | INFO | "** Checking FPR output with expected QA output... **"
# 23:38:22 | INFO | "  254 SEED subreddits in output"
# 23:38:22 | INFO | "  254 SEED subreddits expected"
# 23:38:22 | INFO | "SEED subreddit IDS match expected output"
# 23:38:22 | INFO | "  116 RECOMMEND subreddits in output"
# 23:38:22 | INFO | "  116 RECOMMEND subreddits expected"
# 23:38:22 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:38:22 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/FR_2022-07-26_233458.json"
# 23:38:22 | INFO | "Upload complete!"
# 23:38:22 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:38:22 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:38:23 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:38:23 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  30%|██▉       | 8/27 [03:24<07:19, 23.14s/it]23:38:23 | INFO | "== Country: IT =="
# 23:38:23 | INFO | "Getting geo-relevant subreddits in model for IT..."
# 23:38:26 | INFO | " (232, 160)  <- df_shape"
# 23:38:26 | INFO | " (232, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:38:26 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:09,  2.49s/it]
#  40%|████      | 2/5 [00:05<00:07,  2.53s/it]
#  60%|██████    | 3/5 [00:07<00:05,  2.56s/it]
#  80%|████████  | 4/5 [00:10<00:02,  2.62s/it]
# 100%|██████████| 5/5 [00:12<00:00,  2.58s/it]
# 23:38:39 | INFO | "  8 <-- Optimal N"
# 23:38:39 | INFO | "Assigning clusters based on optimal N..."
# 23:38:41 | INFO | "Getting QA and summary at cluster_level..."
# 23:38:41 | INFO | "(37, 23)  <- df.shape full summary"
# 23:38:41 | INFO | "Adding metadata to df_top_level_summary..."
# 23:38:41 | INFO | "Creating FPR output..."
# 23:38:42 | INFO | "  (214, 15) <- df_fpr.shape"
# 23:38:42 | INFO | "** Checking FPR output with expected QA output... **"
# 23:38:42 | INFO | "  214 SEED subreddits in output"
# 23:38:42 | INFO | "  214 SEED subreddits expected"
# 23:38:42 | INFO | "SEED subreddit IDS match expected output"
# 23:38:42 | INFO | "  116 RECOMMEND subreddits in output"
# 23:38:42 | INFO | "  116 RECOMMEND subreddits expected"
# 23:38:42 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:38:42 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/IT_2022-07-26_233458.json"
# 23:38:42 | INFO | "Upload complete!"
# 23:38:42 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:38:42 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:38:42 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:38:43 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  33%|███▎      | 9/27 [03:44<06:38, 22.12s/it]23:38:43 | INFO | "== Country: MX =="
# 23:38:43 | INFO | "Getting geo-relevant subreddits in model for MX..."
# 23:38:46 | INFO | " (246, 160)  <- df_shape"
# 23:38:46 | INFO | " (246, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:38:46 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:10,  2.69s/it]
#  40%|████      | 2/5 [00:05<00:07,  2.64s/it]
#  60%|██████    | 3/5 [00:07<00:05,  2.64s/it]
#  80%|████████  | 4/5 [00:10<00:02,  2.65s/it]
# 100%|██████████| 5/5 [00:13<00:00,  2.64s/it]
# 23:38:59 | INFO | "  8 <-- Optimal N"
# 23:38:59 | INFO | "Assigning clusters based on optimal N..."
# 23:39:02 | INFO | "Getting QA and summary at cluster_level..."
# 23:39:02 | INFO | "(39, 23)  <- df.shape full summary"
# 23:39:02 | INFO | "Adding metadata to df_top_level_summary..."
# 23:39:02 | INFO | "Creating FPR output..."
# 23:39:02 | INFO | "  (211, 15) <- df_fpr.shape"
# 23:39:02 | INFO | "** Checking FPR output with expected QA output... **"
# 23:39:02 | INFO | "  211 SEED subreddits in output"
# 23:39:02 | INFO | "  211 SEED subreddits expected"
# 23:39:02 | INFO | "SEED subreddit IDS match expected output"
# 23:39:02 | INFO | "   76 RECOMMEND subreddits in output"
# 23:39:02 | INFO | "   76 RECOMMEND subreddits expected"
# 23:39:02 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:39:02 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/MX_2022-07-26_233458.json"
# 23:39:02 | INFO | "Upload complete!"
# 23:39:02 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:39:03 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:39:03 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:39:03 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  37%|███▋      | 10/27 [04:04<06:06, 21.58s/it]23:39:03 | INFO | "== Country: ES =="
# 23:39:03 | INFO | "Getting geo-relevant subreddits in model for ES..."
# 23:39:06 | INFO | " (212, 160)  <- df_shape"
# 23:39:06 | INFO | " (212, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:39:06 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:10,  2.51s/it]
#  40%|████      | 2/5 [00:04<00:07,  2.48s/it]
#  60%|██████    | 3/5 [00:07<00:04,  2.49s/it]
#  80%|████████  | 4/5 [00:10<00:02,  2.50s/it]
# 100%|██████████| 5/5 [00:12<00:00,  2.50s/it]
# 23:39:19 | INFO | "  5 <-- Optimal N"
# 23:39:19 | INFO | "Assigning clusters based on optimal N..."
# 23:39:21 | INFO | "Getting QA and summary at cluster_level..."
# 23:39:21 | INFO | "(43, 23)  <- df.shape full summary"
# 23:39:21 | INFO | "Adding metadata to df_top_level_summary..."
# 23:39:21 | INFO | "Creating FPR output..."
# 23:39:21 | INFO | "  (180, 15) <- df_fpr.shape"
# 23:39:21 | INFO | "** Checking FPR output with expected QA output... **"
# 23:39:21 | INFO | "  180 SEED subreddits in output"
# 23:39:21 | INFO | "  180 SEED subreddits expected"
# 23:39:21 | INFO | "SEED subreddit IDS match expected output"
# 23:39:21 | INFO | "  113 RECOMMEND subreddits in output"
# 23:39:21 | INFO | "  113 RECOMMEND subreddits expected"
# 23:39:21 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:39:22 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/ES_2022-07-26_233458.json"
# 23:39:22 | INFO | "Upload complete!"
# 23:39:22 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:39:22 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:39:22 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:39:22 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  41%|████      | 11/27 [04:24<05:34, 20.90s/it]23:39:23 | INFO | "== Country: AR =="
# 23:39:23 | INFO | "Getting geo-relevant subreddits in model for AR..."
# 23:39:25 | INFO | " (107, 160)  <- df_shape"
# 23:39:25 | INFO | " (107, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:39:25 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:08,  2.18s/it]
#  40%|████      | 2/5 [00:04<00:06,  2.19s/it]
#  60%|██████    | 3/5 [00:06<00:04,  2.27s/it]
#  80%|████████  | 4/5 [00:08<00:02,  2.25s/it]
# 100%|██████████| 5/5 [00:11<00:00,  2.24s/it]
# 23:39:36 | INFO | "  6 <-- Optimal N"
# 23:39:36 | INFO | "Assigning clusters based on optimal N..."
# 23:39:40 | INFO | "Getting QA and summary at cluster_level..."
# 23:39:40 | INFO | "(30, 23)  <- df.shape full summary"
# 23:39:40 | INFO | "Adding metadata to df_top_level_summary..."
# 23:39:40 | INFO | "Creating FPR output..."
# 23:39:40 | INFO | "  (77, 15) <- df_fpr.shape"
# 23:39:40 | INFO | "** Checking FPR output with expected QA output... **"
# 23:39:40 | INFO | "   77 SEED subreddits in output"
# 23:39:40 | INFO | "   77 SEED subreddits expected"
# 23:39:40 | INFO | "SEED subreddit IDS match expected output"
# 23:39:40 | INFO | "   32 RECOMMEND subreddits in output"
# 23:39:40 | INFO | "   32 RECOMMEND subreddits expected"
# 23:39:40 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:39:40 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/AR_2022-07-26_233458.json"
# 23:39:40 | INFO | "Upload complete!"
# 23:39:40 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:39:41 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:39:41 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:39:41 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  44%|████▍     | 12/27 [04:42<05:03, 20.21s/it]23:39:41 | INFO | "== Country: CO =="
# 23:39:41 | INFO | "Getting geo-relevant subreddits in model for CO..."
# 23:39:43 | INFO | " (36, 160)  <- df_shape"
# 23:39:43 | INFO | " (36, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:39:43 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:08,  2.01s/it]
#  40%|████      | 2/5 [00:03<00:05,  1.97s/it]
#  60%|██████    | 3/5 [00:06<00:04,  2.00s/it]
#  80%|████████  | 4/5 [00:08<00:02,  2.01s/it]
# 100%|██████████| 5/5 [00:10<00:00,  2.02s/it]
# 23:39:54 | INFO | "  5 <-- Optimal N"
# 23:39:54 | INFO | "Assigning clusters based on optimal N..."
# 23:39:56 | INFO | "Getting QA and summary at cluster_level..."
# 23:39:56 | INFO | "(18, 23)  <- df.shape full summary"
# 23:39:56 | INFO | "Adding metadata to df_top_level_summary..."
# 23:39:56 | INFO | "Creating FPR output..."
# 23:39:56 | INFO | "  (10, 15) <- df_fpr.shape"
# 23:39:56 | INFO | "** Checking FPR output with expected QA output... **"
# 23:39:56 | INFO | "   10 SEED subreddits in output"
# 23:39:56 | INFO | "   10 SEED subreddits expected"
# 23:39:56 | INFO | "SEED subreddit IDS match expected output"
# 23:39:56 | INFO | "    8 RECOMMEND subreddits in output"
# 23:39:56 | INFO | "    8 RECOMMEND subreddits expected"
# 23:39:56 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:39:56 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/CO_2022-07-26_233458.json"
# 23:39:56 | INFO | "Upload complete!"
# 23:39:56 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:39:57 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:39:57 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:39:57 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  48%|████▊     | 13/27 [04:58<04:24, 18.90s/it]23:39:57 | INFO | "== Country: CR =="
# 23:39:57 | INFO | "Getting geo-relevant subreddits in model for CR..."
# 23:40:05 | INFO | " (29, 160)  <- df_shape"
# 23:40:05 | INFO | " (29, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:40:05 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:08,  2.08s/it]
#  40%|████      | 2/5 [00:04<00:06,  2.02s/it]
#  60%|██████    | 3/5 [00:06<00:04,  2.26s/it]
#  80%|████████  | 4/5 [00:08<00:02,  2.29s/it]
# 100%|██████████| 5/5 [00:12<00:00,  2.42s/it]
# 23:40:17 | INFO | "  5 <-- Optimal N"
# 23:40:17 | INFO | "Assigning clusters based on optimal N..."
# 23:40:20 | INFO | "Getting QA and summary at cluster_level..."
# 23:40:20 | INFO | "(12, 23)  <- df.shape full summary"
# 23:40:20 | INFO | "Adding metadata to df_top_level_summary..."
# 23:40:20 | INFO | "Creating FPR output..."
# 23:40:20 | INFO | "  (20, 15) <- df_fpr.shape"
# 23:40:20 | INFO | "** Checking FPR output with expected QA output... **"
# 23:40:20 | INFO | "   20 SEED subreddits in output"
# 23:40:20 | INFO | "   20 SEED subreddits expected"
# 23:40:20 | INFO | "SEED subreddit IDS match expected output"
# 23:40:20 | INFO | "   13 RECOMMEND subreddits in output"
# 23:40:20 | INFO | "   13 RECOMMEND subreddits expected"
# 23:40:20 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:40:20 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/CR_2022-07-26_233458.json"
# 23:40:20 | INFO | "Upload complete!"
# 23:40:20 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:40:20 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:40:21 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:40:21 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  52%|█████▏    | 14/27 [05:22<04:25, 20.42s/it]23:40:21 | INFO | "== Country: PA =="
# 23:40:21 | INFO | "Getting geo-relevant subreddits in model for PA..."
# 23:40:29 | INFO | " (52, 160)  <- df_shape"
# 23:40:29 | INFO | " (52, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:40:29 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:08,  2.20s/it]
#  40%|████      | 2/5 [00:04<00:06,  2.13s/it]
#  60%|██████    | 3/5 [00:06<00:04,  2.10s/it]
#  80%|████████  | 4/5 [00:08<00:02,  2.10s/it]
# 100%|██████████| 5/5 [00:10<00:00,  2.12s/it]
# 23:40:39 | INFO | "  5 <-- Optimal N"
# 23:40:39 | INFO | "Assigning clusters based on optimal N..."
# 23:40:42 | INFO | "Getting QA and summary at cluster_level..."
# 23:40:42 | INFO | "(26, 23)  <- df.shape full summary"
# 23:40:42 | INFO | "Adding metadata to df_top_level_summary..."
# 23:40:42 | INFO | "Creating FPR output..."
# 23:40:42 | INFO | "  (31, 15) <- df_fpr.shape"
# 23:40:42 | INFO | "** Checking FPR output with expected QA output... **"
# 23:40:42 | INFO | "   31 SEED subreddits in output"
# 23:40:42 | INFO | "   31 SEED subreddits expected"
# 23:40:42 | INFO | "SEED subreddit IDS match expected output"
# 23:40:42 | INFO | "   27 RECOMMEND subreddits in output"
# 23:40:42 | INFO | "   27 RECOMMEND subreddits expected"
# 23:40:42 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:40:42 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/PA_2022-07-26_233458.json"
# 23:40:42 | INFO | "Upload complete!"
# 23:40:42 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:40:42 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:40:43 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:40:43 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  56%|█████▌    | 15/27 [05:44<04:11, 20.93s/it]23:40:43 | INFO | "== Country: SE =="
# 23:40:43 | INFO | "Getting geo-relevant subreddits in model for SE..."
# 23:40:46 | INFO | " (283, 160)  <- df_shape"
# 23:40:46 | INFO | " (283, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:40:46 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:11,  2.87s/it]
#  40%|████      | 2/5 [00:05<00:08,  2.80s/it]
#  60%|██████    | 3/5 [00:08<00:05,  2.83s/it]
#  80%|████████  | 4/5 [00:11<00:02,  2.84s/it]
# 100%|██████████| 5/5 [00:14<00:00,  2.83s/it]
# 23:41:00 | INFO | "  5 <-- Optimal N"
# 23:41:00 | INFO | "Assigning clusters based on optimal N..."
# 23:41:05 | INFO | "Getting QA and summary at cluster_level..."
# 23:41:05 | INFO | "(53, 23)  <- df.shape full summary"
# 23:41:05 | INFO | "Adding metadata to df_top_level_summary..."
# 23:41:05 | INFO | "Creating FPR output..."
# 23:41:05 | INFO | "  (263, 15) <- df_fpr.shape"
# 23:41:05 | INFO | "** Checking FPR output with expected QA output... **"
# 23:41:05 | INFO | "  263 SEED subreddits in output"
# 23:41:05 | INFO | "  263 SEED subreddits expected"
# 23:41:05 | INFO | "SEED subreddit IDS match expected output"
# 23:41:05 | INFO | "  162 RECOMMEND subreddits in output"
# 23:41:05 | INFO | "  162 RECOMMEND subreddits expected"
# 23:41:05 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:41:05 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/SE_2022-07-26_233458.json"
# 23:41:05 | INFO | "Upload complete!"
# 23:41:05 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:41:05 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:41:06 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:41:06 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  59%|█████▉    | 16/27 [06:07<03:56, 21.51s/it]23:41:06 | INFO | "== Country: RO =="
# 23:41:06 | INFO | "Getting geo-relevant subreddits in model for RO..."
# 23:41:08 | INFO | " (129, 160)  <- df_shape"
# 23:41:08 | INFO | " (129, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:41:08 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:09,  2.42s/it]
#  40%|████      | 2/5 [00:04<00:07,  2.34s/it]
#  60%|██████    | 3/5 [00:06<00:04,  2.28s/it]
#  80%|████████  | 4/5 [00:09<00:02,  2.25s/it]
# 100%|██████████| 5/5 [00:11<00:00,  2.28s/it]
# 23:41:20 | INFO | "  5 <-- Optimal N"
# 23:41:20 | INFO | "Assigning clusters based on optimal N..."
# 23:41:22 | INFO | "Getting QA and summary at cluster_level..."
# 23:41:22 | INFO | "(32, 23)  <- df.shape full summary"
# 23:41:22 | INFO | "Adding metadata to df_top_level_summary..."
# 23:41:22 | INFO | "Creating FPR output..."
# 23:41:22 | INFO | "  (109, 15) <- df_fpr.shape"
# 23:41:22 | INFO | "** Checking FPR output with expected QA output... **"
# 23:41:22 | INFO | "  109 SEED subreddits in output"
# 23:41:22 | INFO | "  109 SEED subreddits expected"
# 23:41:22 | INFO | "SEED subreddit IDS match expected output"
# 23:41:22 | INFO | "   69 RECOMMEND subreddits in output"
# 23:41:22 | INFO | "   69 RECOMMEND subreddits expected"
# 23:41:22 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:41:22 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/RO_2022-07-26_233458.json"
# 23:41:23 | INFO | "Upload complete!"
# 23:41:23 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:41:23 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:41:23 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:41:23 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  63%|██████▎   | 17/27 [06:25<03:22, 20.29s/it]23:41:24 | INFO | "== Country: NL =="
# 23:41:24 | INFO | "Getting geo-relevant subreddits in model for NL..."
# 23:41:26 | INFO | " (268, 160)  <- df_shape"
# 23:41:26 | INFO | " (268, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:41:26 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:10,  2.63s/it]
#  40%|████      | 2/5 [00:05<00:07,  2.65s/it]
#  60%|██████    | 3/5 [00:07<00:05,  2.65s/it]
#  80%|████████  | 4/5 [00:10<00:02,  2.65s/it]
# 100%|██████████| 5/5 [00:13<00:00,  2.65s/it]
# 23:41:39 | INFO | "  9 <-- Optimal N"
# 23:41:39 | INFO | "Assigning clusters based on optimal N..."
# 23:41:42 | INFO | "Getting QA and summary at cluster_level..."
# 23:41:42 | INFO | "(45, 23)  <- df.shape full summary"
# 23:41:42 | INFO | "Adding metadata to df_top_level_summary..."
# 23:41:42 | INFO | "Creating FPR output..."
# 23:41:42 | INFO | "  (237, 15) <- df_fpr.shape"
# 23:41:42 | INFO | "** Checking FPR output with expected QA output... **"
# 23:41:42 | INFO | "  237 SEED subreddits in output"
# 23:41:42 | INFO | "  237 SEED subreddits expected"
# 23:41:42 | INFO | "SEED subreddit IDS match expected output"
# 23:41:42 | INFO | "  149 RECOMMEND subreddits in output"
# 23:41:42 | INFO | "  149 RECOMMEND subreddits expected"
# 23:41:42 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:41:43 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/NL_2022-07-26_233458.json"
# 23:41:43 | INFO | "Upload complete!"
# 23:41:43 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:41:43 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:41:43 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:41:43 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  67%|██████▋   | 18/27 [06:45<03:02, 20.23s/it]23:41:44 | INFO | "== Country: GR =="
# 23:41:44 | INFO | "Getting geo-relevant subreddits in model for GR..."
# 23:41:46 | INFO | " (80, 160)  <- df_shape"
# 23:41:46 | INFO | " (80, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:41:46 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:08,  2.11s/it]
#  40%|████      | 2/5 [00:04<00:06,  2.17s/it]
#  60%|██████    | 3/5 [00:06<00:04,  2.18s/it]
#  80%|████████  | 4/5 [00:08<00:02,  2.17s/it]
# 100%|██████████| 5/5 [00:10<00:00,  2.17s/it]
# 23:41:57 | INFO | "  5 <-- Optimal N"
# 23:41:57 | INFO | "Assigning clusters based on optimal N..."
# 23:41:59 | INFO | "Getting QA and summary at cluster_level..."
# 23:41:59 | INFO | "(23, 23)  <- df.shape full summary"
# 23:41:59 | INFO | "Adding metadata to df_top_level_summary..."
# 23:41:59 | INFO | "Creating FPR output..."
# 23:41:59 | INFO | "  (69, 15) <- df_fpr.shape"
# 23:41:59 | INFO | "** Checking FPR output with expected QA output... **"
# 23:41:59 | INFO | "   69 SEED subreddits in output"
# 23:41:59 | INFO | "   69 SEED subreddits expected"
# 23:41:59 | INFO | "SEED subreddit IDS match expected output"
# 23:41:59 | INFO | "   43 RECOMMEND subreddits in output"
# 23:41:59 | INFO | "   43 RECOMMEND subreddits expected"
# 23:41:59 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:41:59 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/GR_2022-07-26_233458.json"
# 23:42:00 | INFO | "Upload complete!"
# 23:42:00 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:42:00 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:42:00 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:42:00 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  70%|███████   | 19/27 [07:02<02:33, 19.22s/it]23:42:01 | INFO | "== Country: BE =="
# 23:42:01 | INFO | "Getting geo-relevant subreddits in model for BE..."
# 23:42:03 | INFO | " (150, 160)  <- df_shape"
# 23:42:03 | INFO | " (150, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:42:03 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:09,  2.37s/it]
#  40%|████      | 2/5 [00:04<00:07,  2.39s/it]
#  60%|██████    | 3/5 [00:07<00:04,  2.40s/it]
#  80%|████████  | 4/5 [00:09<00:02,  2.38s/it]
# 100%|██████████| 5/5 [00:11<00:00,  2.38s/it]
# 23:42:15 | INFO | "  8 <-- Optimal N"
# 23:42:15 | INFO | "Assigning clusters based on optimal N..."
# 23:42:18 | INFO | "Getting QA and summary at cluster_level..."
# 23:42:18 | INFO | "(33, 23)  <- df.shape full summary"
# 23:42:18 | INFO | "Adding metadata to df_top_level_summary..."
# 23:42:18 | INFO | "Creating FPR output..."
# 23:42:18 | INFO | "  (130, 15) <- df_fpr.shape"
# 23:42:18 | INFO | "** Checking FPR output with expected QA output... **"
# 23:42:18 | INFO | "  130 SEED subreddits in output"
# 23:42:18 | INFO | "  130 SEED subreddits expected"
# 23:42:18 | INFO | "SEED subreddit IDS match expected output"
# 23:42:18 | INFO | "   94 RECOMMEND subreddits in output"
# 23:42:18 | INFO | "   94 RECOMMEND subreddits expected"
# 23:42:18 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:42:18 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/BE_2022-07-26_233458.json"
# 23:42:18 | INFO | "Upload complete!"
# 23:42:18 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:42:18 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:42:19 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:42:19 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  74%|███████▍  | 20/27 [07:20<02:13, 19.02s/it]23:42:19 | INFO | "== Country: PL =="
# 23:42:19 | INFO | "Getting geo-relevant subreddits in model for PL..."
# 23:42:27 | INFO | " (257, 160)  <- df_shape"
# 23:42:27 | INFO | " (257, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:42:27 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:10,  2.61s/it]
#  40%|████      | 2/5 [00:05<00:07,  2.54s/it]
#  60%|██████    | 3/5 [00:07<00:05,  2.51s/it]
#  80%|████████  | 4/5 [00:10<00:02,  2.50s/it]
# 100%|██████████| 5/5 [00:12<00:00,  2.55s/it]
# 23:42:40 | INFO | "  9 <-- Optimal N"
# 23:42:40 | INFO | "Assigning clusters based on optimal N..."
# 23:42:43 | INFO | "Getting QA and summary at cluster_level..."
# 23:42:43 | INFO | "(34, 23)  <- df.shape full summary"
# 23:42:43 | INFO | "Adding metadata to df_top_level_summary..."
# 23:42:43 | INFO | "Creating FPR output..."
# 23:42:43 | INFO | "  (242, 15) <- df_fpr.shape"
# 23:42:43 | INFO | "** Checking FPR output with expected QA output... **"
# 23:42:43 | INFO | "  242 SEED subreddits in output"
# 23:42:43 | INFO | "  242 SEED subreddits expected"
# 23:42:43 | INFO | "SEED subreddit IDS match expected output"
# 23:42:43 | INFO | "  190 RECOMMEND subreddits in output"
# 23:42:43 | INFO | "  190 RECOMMEND subreddits expected"
# 23:42:43 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:42:43 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/PL_2022-07-26_233458.json"
# 23:42:43 | INFO | "Upload complete!"
# 23:42:43 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:42:43 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:42:44 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:42:44 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  78%|███████▊  | 21/27 [07:45<02:04, 20.81s/it]23:42:44 | INFO | "== Country: TR =="
# 23:42:44 | INFO | "Getting geo-relevant subreddits in model for TR..."
# 23:42:46 | INFO | " (186, 160)  <- df_shape"
# 23:42:46 | INFO | " (186, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:42:46 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:10,  2.57s/it]
#  40%|████      | 2/5 [00:05<00:07,  2.54s/it]
#  60%|██████    | 3/5 [00:07<00:05,  2.56s/it]
#  80%|████████  | 4/5 [00:10<00:02,  2.58s/it]
# 100%|██████████| 5/5 [00:12<00:00,  2.57s/it]
# 23:42:59 | INFO | "  5 <-- Optimal N"
# 23:42:59 | INFO | "Assigning clusters based on optimal N..."
# 23:43:02 | INFO | "Getting QA and summary at cluster_level..."
# 23:43:02 | INFO | "(41, 23)  <- df.shape full summary"
# 23:43:02 | INFO | "Adding metadata to df_top_level_summary..."
# 23:43:02 | INFO | "Creating FPR output..."
# 23:43:02 | INFO | "  (114, 15) <- df_fpr.shape"
# 23:43:02 | INFO | "** Checking FPR output with expected QA output... **"
# 23:43:02 | INFO | "  114 SEED subreddits in output"
# 23:43:02 | INFO | "  114 SEED subreddits expected"
# 23:43:02 | INFO | "SEED subreddit IDS match expected output"
# 23:43:02 | INFO | "   51 RECOMMEND subreddits in output"
# 23:43:02 | INFO | "   51 RECOMMEND subreddits expected"
# 23:43:02 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:43:03 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/TR_2022-07-26_233458.json"
# 23:43:03 | INFO | "Upload complete!"
# 23:43:03 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:43:03 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:43:03 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:43:03 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  81%|████████▏ | 22/27 [08:05<01:42, 20.46s/it]23:43:04 | INFO | "== Country: SA =="
# 23:43:04 | INFO | "Getting geo-relevant subreddits in model for SA..."
# 23:43:12 | INFO | " (257, 160)  <- df_shape"
# 23:43:12 | INFO | " (257, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:43:12 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:10,  2.65s/it]
#  40%|████      | 2/5 [00:05<00:07,  2.58s/it]
#  60%|██████    | 3/5 [00:07<00:05,  2.59s/it]
#  80%|████████  | 4/5 [00:10<00:02,  2.61s/it]
# 100%|██████████| 5/5 [00:12<00:00,  2.60s/it]
# 23:43:25 | INFO | "  5 <-- Optimal N"
# 23:43:25 | INFO | "Assigning clusters based on optimal N..."
# 23:43:28 | INFO | "Getting QA and summary at cluster_level..."
# 23:43:28 | INFO | "(52, 23)  <- df.shape full summary"
# 23:43:28 | INFO | "Adding metadata to df_top_level_summary..."
# 23:43:28 | INFO | "Creating FPR output..."
# 23:43:28 | INFO | "  (235, 15) <- df_fpr.shape"
# 23:43:28 | INFO | "** Checking FPR output with expected QA output... **"
# 23:43:28 | INFO | "  235 SEED subreddits in output"
# 23:43:28 | INFO | "  235 SEED subreddits expected"
# 23:43:28 | INFO | "SEED subreddit IDS match expected output"
# 23:43:28 | INFO | "  155 RECOMMEND subreddits in output"
# 23:43:28 | INFO | "  155 RECOMMEND subreddits expected"
# 23:43:28 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:43:28 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/SA_2022-07-26_233458.json"
# 23:43:28 | INFO | "Upload complete!"
# 23:43:28 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:43:28 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:43:29 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:43:29 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  85%|████████▌ | 23/27 [08:30<01:27, 21.97s/it]23:43:29 | INFO | "== Country: PH =="
# 23:43:29 | INFO | "Getting geo-relevant subreddits in model for PH..."
# 23:43:33 | INFO | " (783, 160)  <- df_shape"
# 23:43:33 | INFO | " (783, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:43:33 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:03<00:15,  3.92s/it]
#  40%|████      | 2/5 [00:07<00:11,  3.89s/it]
#  60%|██████    | 3/5 [00:11<00:07,  3.86s/it]
#  80%|████████  | 4/5 [00:16<00:04,  4.23s/it]
# 100%|██████████| 5/5 [00:20<00:00,  4.20s/it]
# 23:43:54 | INFO | "  5 <-- Optimal N"
# 23:43:54 | INFO | "Assigning clusters based on optimal N..."
# 23:43:58 | INFO | "Getting QA and summary at cluster_level..."
# 23:43:58 | INFO | "(112, 23)  <- df.shape full summary"
# 23:43:58 | INFO | "Adding metadata to df_top_level_summary..."
# 23:43:58 | INFO | "Creating FPR output..."
# 23:43:58 | INFO | "  (765, 15) <- df_fpr.shape"
# 23:43:58 | INFO | "** Checking FPR output with expected QA output... **"
# 23:43:58 | INFO | "  765 SEED subreddits in output"
# 23:43:58 | INFO | "  765 SEED subreddits expected"
# 23:43:58 | INFO | "SEED subreddit IDS match expected output"
# 23:43:58 | INFO | "  541 RECOMMEND subreddits in output"
# 23:43:58 | INFO | "  541 RECOMMEND subreddits expected"
# 23:43:58 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:43:58 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/PH_2022-07-26_233458.json"
# 23:43:59 | INFO | "Upload complete!"
# 23:43:59 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:43:59 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:43:59 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:43:59 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  89%|████████▉ | 24/27 [09:01<01:13, 24.47s/it]23:44:00 | INFO | "== Country: GT =="
# 23:44:00 | INFO | "Getting geo-relevant subreddits in model for GT..."
# 23:44:06 | INFO | " (61, 160)  <- df_shape"
# 23:44:06 | INFO | " (61, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:44:06 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:08,  2.09s/it]
#  40%|████      | 2/5 [00:04<00:06,  2.11s/it]
#  60%|██████    | 3/5 [00:06<00:04,  2.10s/it]
#  80%|████████  | 4/5 [00:08<00:02,  2.08s/it]
# 100%|██████████| 5/5 [00:10<00:00,  2.11s/it]
# 23:44:17 | INFO | "  6 <-- Optimal N"
# 23:44:17 | INFO | "Assigning clusters based on optimal N..."
# 23:44:19 | INFO | "Getting QA and summary at cluster_level..."
# 23:44:19 | INFO | "(26, 23)  <- df.shape full summary"
# 23:44:19 | INFO | "Adding metadata to df_top_level_summary..."
# 23:44:19 | INFO | "Creating FPR output..."
# 23:44:20 | INFO | "  (37, 15) <- df_fpr.shape"
# 23:44:20 | INFO | "** Checking FPR output with expected QA output... **"
# 23:44:20 | INFO | "   37 SEED subreddits in output"
# 23:44:20 | INFO | "   37 SEED subreddits expected"
# 23:44:20 | INFO | "SEED subreddit IDS match expected output"
# 23:44:20 | INFO | "   24 RECOMMEND subreddits in output"
# 23:44:20 | INFO | "   24 RECOMMEND subreddits expected"
# 23:44:20 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:44:20 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/GT_2022-07-26_233458.json"
# 23:44:20 | INFO | "Upload complete!"
# 23:44:20 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:44:20 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:44:20 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:44:21 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  93%|█████████▎| 25/27 [09:22<00:47, 23.56s/it]23:44:21 | INFO | "== Country: CL =="
# 23:44:21 | INFO | "Getting geo-relevant subreddits in model for CL..."
# 23:44:30 | INFO | " (81, 160)  <- df_shape"
# 23:44:30 | INFO | " (81, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:44:30 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:02<00:08,  2.08s/it]
#  40%|████      | 2/5 [00:04<00:06,  2.16s/it]
#  60%|██████    | 3/5 [00:06<00:04,  2.20s/it]
#  80%|████████  | 4/5 [00:08<00:02,  2.18s/it]
# 100%|██████████| 5/5 [00:10<00:00,  2.20s/it]
# 23:44:41 | INFO | "  5 <-- Optimal N"
# 23:44:41 | INFO | "Assigning clusters based on optimal N..."
# 23:44:43 | INFO | "Getting QA and summary at cluster_level..."
# 23:44:43 | INFO | "(27, 23)  <- df.shape full summary"
# 23:44:43 | INFO | "Adding metadata to df_top_level_summary..."
# 23:44:43 | INFO | "Creating FPR output..."
# 23:44:43 | INFO | "  (47, 15) <- df_fpr.shape"
# 23:44:43 | INFO | "** Checking FPR output with expected QA output... **"
# 23:44:43 | INFO | "   47 SEED subreddits in output"
# 23:44:43 | INFO | "   47 SEED subreddits expected"
# 23:44:43 | INFO | "SEED subreddit IDS match expected output"
# 23:44:43 | INFO | "   30 RECOMMEND subreddits in output"
# 23:44:43 | INFO | "   30 RECOMMEND subreddits expected"
# 23:44:43 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:44:43 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/CL_2022-07-26_233458.json"
# 23:44:44 | INFO | "Upload complete!"
# 23:44:44 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:44:44 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:44:44 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:44:45 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
#  96%|█████████▋| 26/27 [09:46<00:23, 23.64s/it]23:44:45 | INFO | "== Country: FI =="
# 23:44:45 | INFO | "Getting geo-relevant subreddits in model for FI..."
# 23:44:54 | INFO | " (526, 160)  <- df_shape"
# 23:44:54 | INFO | " (526, 161) <- Shape AFTER dropping subreddits with covid in title"
# 23:44:54 | INFO | "Finding optimal N (target # of subs per cluster)..."
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:03<00:13,  3.33s/it]
#  40%|████      | 2/5 [00:06<00:10,  3.42s/it]
#  60%|██████    | 3/5 [00:10<00:07,  3.54s/it]
#  80%|████████  | 4/5 [00:13<00:03,  3.51s/it]
# 100%|██████████| 5/5 [00:18<00:00,  3.73s/it]
# 23:45:13 | INFO | "  8 <-- Optimal N"
# 23:45:13 | INFO | "Assigning clusters based on optimal N..."
# 23:45:17 | INFO | "Getting QA and summary at cluster_level..."
# 23:45:17 | INFO | "(65, 23)  <- df.shape full summary"
# 23:45:17 | INFO | "Adding metadata to df_top_level_summary..."
# 23:45:17 | INFO | "Creating FPR output..."
# 23:45:17 | INFO | "  (514, 15) <- df_fpr.shape"
# 23:45:17 | INFO | "** Checking FPR output with expected QA output... **"
# 23:45:17 | INFO | "  514 SEED subreddits in output"
# 23:45:17 | INFO | "  514 SEED subreddits expected"
# 23:45:17 | INFO | "SEED subreddit IDS match expected output"
# 23:45:17 | INFO | "  350 RECOMMEND subreddits in output"
# 23:45:17 | INFO | "  350 RECOMMEND subreddits expected"
# 23:45:17 | INFO | "RECOMMEND subreddit IDS match expected output"
# 23:45:17 | INFO | "Saving FRP file to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/fpr_json/FI_2022-07-26_233458.json"
# 23:45:18 | INFO | "Upload complete!"
# 23:45:18 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr"
# 23:45:18 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_qa_summary"
# 23:45:18 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_fpr_cluster_summary"
# 23:45:18 | INFO | "Saving to:
#   i18n_topic_model_batch/fpr/runs/2022-07-26_233458/df_dynamic_clusters"
# 100%|██████████| 27/27 [10:20<00:00, 22.97s/it]
# CPU times: user 7min 46s, sys: 5.28 s, total: 7min 51s
# Wall time: 10min 20s

# %%
f"test2"
# Out:
# 'test2'

# %%
f"test"
# Out:
# 'test'
